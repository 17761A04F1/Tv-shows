# %%
import pandas as pd
import seaborn as sns

# %%
df=pd.read_csv('/content/IMDd Top Indian TV Shows.csv')

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Name', 'Duration', 'Genre', 'Rating', 'No. of Ratings',
#        'No. of Episodes', 'Creators', 'Stars', 'Reviews (Users)',
#        'Reviews (Critics)', 'Seasons', 'Storyline', 'Language',
#        'Release Date'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# Unnamed: 0             0
# Name                   0
# Duration             166
# Genre                  0
# Rating                36
# No. of Ratings        36
# No. of Episodes        0
# Creators             406
# Stars                  4
# Reviews (Users)       99
# Reviews (Critics)    318
# Seasons               41
# Storyline             34
# Language              14
# Release Date          22
# dtype: int64

# %%
df.drop('Unnamed: 0',axis=1,inplace=True)

# %%
df
# Out:
#                                           Name Duration  \
# 0                               The Family Man    45min
# 1           Scam 1992: The Harshad Mehta Story    54min
# 2                         Broken But Beautiful    22min
# 3                                    Aspirants    45min
# 4                                     Maharani      NaN
# ..                                         ...      ...
# 495                     These Black Black Eyes      NaN
# 496  Brahmarakshas 2 - Phir Jaag Utha Shaitaan    45min
# 497               Spotlight: Bollywood Exposed      NaN
# 498                              Hello Friends    18min
# 499                        Chandragupta Maurya    48min
#
#                                Genre  Rating  No. of Ratings  No. of Episodes  \
# 0      ['Action', 'Comedy', 'Drama']     8.8         57797.0               19
# 1    ['Biography', 'Crime', 'Drama']     9.5        109950.0               10
# ...

# %%
df.dropna(axis=0,inplace=True)

# %%
df
# Out:
#                                    Name Duration  \
# 0                        The Family Man    45min
# 3                             Aspirants    45min
# 6                              Mirzapur       1h
# 7                        November Story    40min
# 9                          Sacred Games    50min
# 10                          Special OPS    49min
# 11      Asur: Welcome to Your Dark Side    43min
# 12                           Paatal Lok    44min
# 13                         Kota Factory    45min
# 20                          Delhi Crime    50min
# 21                              Undekhi    32min
# 23                       Puppy Dog Pals    24min
# 28                                Aarya    51min
# 29               Mickey Mouse Clubhouse    30min
# 30                       Made in Heaven    50min
# 33                          Inside Edge    45min
# 35                      Bandish Bandits    30min
# 36                               Gullak    24min
# ...

# %%
sns.barplot(x='Language',y='Rating',data=df)
# Out:
# <Axes: xlabel='Language', ylabel='Rating'>

# %%
sns.heatmap(df.corr())
# Out:
# <ipython-input-48-aa4f4450a243>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr())
# <Axes: >

# %%
df1=df2 = df.sort_values('Rating', ascending=False)
df1
# Out:
#                                    Name Duration  \
# 13                         Kota Factory    45min
# 36                               Gullak    24min
# 90                              Ramayan    30min
# 44                      Yeh Meri Family    30min
# 3                             Aspirants    45min
# 58                           Mahabharat    20min
# 0                        The Family Man    45min
# 132                    Bose: Dead/Alive    20min
# 84           Kuch Rang Pyar Ke Aise Bhi    22min
# 35                      Bandish Bandits    30min
# 62                  Permanent Roommates    21min
# 10                          Special OPS    49min
# 9                          Sacred Games    50min
# 11      Asur: Welcome to Your Dark Side    43min
# 20                          Delhi Crime    50min
# 75                        The Test Case    29min
# 6                              Mirzapur       1h
# 105                     Laakhon Mein Ek    30min
# ...

# %% [markdown]
# # Top 10 shows with highest imdb

# %%
df2=df1.head(10)
import matplotlib.pyplot as plt

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Set the figure size
fig, ax = plt.subplots(figsize=(22,6))

# Create the bar plot
sns.barplot(x='Name', y='Rating', data=df2, ax=ax,hue='Language')

# Show the plot
plt.show()
